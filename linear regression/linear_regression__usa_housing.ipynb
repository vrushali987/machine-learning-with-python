# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('USA_Housing.csv')
df=pd.read_csv("H:\Python Tutorial\Python_libraries\pandas\pandas-with-data-science-ai.ipynb")

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
# Avg. Area Income                5000 non-null float64
# Avg. Area House Age             5000 non-null float64
# Avg. Area Number of Rooms       5000 non-null float64
# Avg. Area Number of Bedrooms    5000 non-null float64
# Area Population                 5000 non-null float64
# Price                           5000 non-null float64
# Address                         5000 non-null object
# dtypes: float64(6), object(1)
# memory usage: 273.5+ KB

# %%
df.shape
# Out:
# (5000, 7)

# %%
df.drop('Address',axis=1,inplace=True)

# %%
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# 5         80175.754159             4.988408                   6.104512
# 6         64698.463428             6.025336                   8.147760
# 7         78394.339278             6.989780                   6.620478
# 8         59927.660813             5.362126                   6.393121
# 9         81885.927184             4.423672                   8.167688
# 10        80527.472083             8.093513                   5.042747
# 11        50593.695497             4.496513                   7.467627
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()

# %%
scaled_array=ss.fit_transform(df.drop('Price',axis=1))

# %%
scaled_array.shape
# Out:
# (5000, 5)

# %%
df.columns[:-1]
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population'],
#       dtype='object')

# %%
X=pd.DataFrame(data=scaled_array,columns=df.columns[:-1])

# %%
X.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          1.028660            -0.296927                   0.021274
# 1          1.000808             0.025902                  -0.255506
# 2         -0.684629            -0.112303                   1.516243
# 3         -0.491499             1.221572                  -1.393077
# 4         -0.807073            -0.944834                   0.846742
#
#    Avg. Area Number of Bedrooms  Area Population
# 0                      0.088062        -1.317599
# 1                     -0.722301         0.403999
# 2                      0.930840         0.072410
# 3                     -0.584540        -0.186734
# 4                      0.201513        -0.988387

# %%
y=df['Price']

# %%
y
# Out:
# 0       1.059034e+06
# 1       1.505891e+06
# 2       1.058988e+06
# 3       1.260617e+06
# 4       6.309435e+05
# 5       1.068138e+06
# 6       1.502056e+06
# 7       1.573937e+06
# 8       7.988695e+05
# 9       1.545155e+06
# 10      1.707046e+06
# 11      6.637324e+05
# 12      1.042814e+06
# 13      1.291332e+06
# 14      1.402818e+06
# 15      1.306675e+06
# 16      1.556787e+06
# 17      5.284852e+05
# 18      1.019426e+06
# 19      1.030591e+06
# 20      2.146925e+06
# 21      9.292476e+05
# 22      7.188872e+05
# 23      7.439998e+05
# 24      8.957371e+05
# 25      1.453975e+06
# 26      1.125693e+06
# 27      9.754295e+05
# 28      1.240764e+06
# 29      1.577018e+06
#             ...
# 4970    1.120943e+06
# 4971    1.111307e+06
# 4972    1.736402e+06
# 4973    1.340770e+06
# 4974    8.013486e+05
# 4975    1.324382e+06
# 4976    1.340344e+06
# 4977    1.518478e+06
# 4978    1.910585e+06
# 4979    1.823498e+06
# 4980    1.406865e+06
# 4981    1.203850e+06
# ...

# %%
df.corr()
# Out:
#                               Avg. Area Income  Avg. Area House Age  \
# Avg. Area Income                      1.000000            -0.002007
# Avg. Area House Age                  -0.002007             1.000000
# Avg. Area Number of Rooms            -0.011032            -0.009428
# Avg. Area Number of Bedrooms          0.019788             0.006149
# Area Population                      -0.016234            -0.018743
# Price                                 0.639734             0.452543
#
#                               Avg. Area Number of Rooms  \
# Avg. Area Income                              -0.011032
# Avg. Area House Age                           -0.009428
# Avg. Area Number of Rooms                      1.000000
# Avg. Area Number of Bedrooms                   0.462695
# Area Population                                0.002040
# Price                                          0.335664
#
#                               Avg. Area Number of Bedrooms  Area Population  \
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(data=df.corr(),cmap='coolwarm')

# %%
X.drop('Avg.Area Number of Bedrooms',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-24c9ee442eab> in <module>
# ----> 1 X.drop('Avg.Area Number of Bedrooms',axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
X.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          1.028660            -0.296927                   0.021274
# 1          1.000808             0.025902                  -0.255506
# 2         -0.684629            -0.112303                   1.516243
# 3         -0.491499             1.221572                  -1.393077
# 4         -0.807073            -0.944834                   0.846742
#
#    Avg. Area Number of Bedrooms  Area Population
# 0                      0.088062        -1.317599
# 1                     -0.722301         0.403999
# 2                      0.930840         0.072410
# 3                     -0.584540        -0.186734
# 4                      0.201513        -0.988387

# %%
 # X.drop('Avg. Area Number of Bedrooms',axis=1,inplace=True)

# %%
X.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          1.028660            -0.296927                   0.021274
# 1          1.000808             0.025902                  -0.255506
# 2         -0.684629            -0.112303                   1.516243
# 3         -0.491499             1.221572                  -1.393077
# 4         -0.807073            -0.944834                   0.846742
#
#    Avg. Area Number of Bedrooms  Area Population
# 0                      0.088062        -1.317599
# 1                     -0.722301         0.403999
# 2                      0.930840         0.072410
# 3                     -0.584540        -0.186734
# 4                      0.201513        -0.988387

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
X_train.shape
# Out:
# (3500, 5)

# %%
X_test.shape
# Out:
# (1500, 5)

# %%
y_train.shape
# Out:
# (3500,)

# %%
y_test.shape
# Out:
# (1500,)

# %%
X_train.head()
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 3334          0.141172            -0.085256                  -0.009940
# 4545         -0.271097             0.463525                  -0.281250
# 3699          0.747183            -0.856412                   0.258104
# 1717          1.451764             0.160389                   0.693371
# 1145          1.666553            -0.467928                   0.257432
#
#       Avg. Area Number of Bedrooms  Area Population
# 3334                     -1.386800         1.758122
# 4545                     -0.681783         0.729818
# 3699                      0.922737         1.442614
# 1717                      1.133431        -1.324023
# 1145                     -0.584540        -0.038607

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
ypred=lr.predict(X_test)

# %%
ypred
# Out:
# array([1391533.0909114 , 1332233.02084579, 1063751.96003734, ...,
#        1454326.57836262, 1390710.37595033, 1274099.86473472])

# %%
len(ypred)
# Out:
# 1500

# %%
len(y_test)
# Out:
# 1500

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(y_test,ypred)

# %%
plt.scatter(ypred,y_test)

# %%
plt.hist(ypred-y_test)
# Out:
# (array([  3.,  18.,  85., 219., 346., 383., 275., 135.,  33.,   3.]),
#  array([-372885.06812605, -301643.92605773, -230402.7839894 ,
#         -159161.64192107,  -87920.49985275,  -16679.35778442,
#           54561.78428391,  125802.92635224,  197044.06842056,
#          268285.21048889,  339526.35255722]),
#  <a list of 10 Patch objects>)

# %%
s=y_test-ypred

# %%
s.mean()
# Out:
# 2867.0094888351064

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test,ypred)
# Out:
# 83583.85232105233
